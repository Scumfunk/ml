# %%
import os
mingw_path = 'C:\\Program Files\\mingw-w64\\x86_64-5.3.0-posix-seh-rt_v4-rev0\\mingw64\\bin'
os.environ['PATH'] = mingw_path + ';' + os.environ['PATH']
# %matplotlib inline
import pandas as pd
import numpy as np
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import sort
import matplotlib
from sklearn import metrics, preprocessing

# %%
data_path = "F:\\Users\\ivann_000\\AnacondaProjects\\MLBootcamp4\\data"
X = pd.read_csv(data_path+"\\x_train.csv", sep=';', header=None)
X_test = pd.read_csv(data_path+"\\x_test.csv", sep=';', header=None)
X = X.append(X_test, ignore_index=True)
y = pd.read_csv(data_path+"\\y_train.csv", sep=';', header=None)[0]

# %%
labels = [0, 1, 2, 3, 4]
c_count = [len(y[y==i]) for i in labels]
c_count
# Out:
# [113, 1164, 1521, 581, 110]

# %%
colors = ['red','green','blue','purple','yellow']

fig = plt.figure(figsize=(15,15))
plt.scatter(X[1], X[96], c=y, cmap=matplotlib.colors.ListedColormap(colors))

# %%
aa = preprocessing.scale(X[3]).reshape(-1,1)
# X[[3]]
# Out:
# array([[-0.19377151],
#        [-1.09200347],
#        [ 0.76998325],
#        ...,
#        [ 0.70255565],
#        [-1.03323879],
#        [ 0.7468065 ]])

# %%
plt.hist(np.sqrt( preprocessing.scale(X[18])*preprocessing.scale(X[18]) + preprocessing.scale(X[17])*preprocessing.scale(X[17]) ).reshape(-1,1),color='red', bins=20)
plt.hist(preprocessing.scale(X[18]).reshape(-1,1), alpha=0.3, bins=20)
plt.hist(preprocessing.scale(X[17]).reshape(-1,1), alpha=0.3, bins=20)
# Out:
# (array([  1.76000000e+02,   1.15000000e+03,   1.49600000e+03,
#           1.76200000e+03,   1.08600000e+03,   1.31000000e+02,
#           1.20000000e+01,   0.00000000e+00,   2.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00]),
#  array([ -2.59830016e+00,  -1.72995537e+00,  -8.61610589e-01,
#           6.73419659e-03,   8.75078982e-01,   1.74342377e+00,
#           2.61176855e+00,   3.48011334e+00,   4.34845813e+00,
#           5.21680291e+00,   6.08514770e+00,   6.95349248e+00,
#           7.82183727e+00,   8.69018205e+00,   9.55852684e+00,
#           1.04268716e+01,   1.12952164e+01,   1.21635612e+01,
#           1.30319060e+01,   1.39002508e+01,   1.47685956e+01]),
#  <a list of 20 Patch objects>)
